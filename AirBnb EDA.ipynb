# %% [markdown]
# # **Project Name**    - **AirBnb Booking Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# **Objective:**
#
# * This project aimed to leverage data analysis of approximately 49,000 Airbnb listings in NYC to optimize host performance, enhance customer satisfaction, and increase overall platform revenue and market competitiveness.
#
# **Dataset:**
#
# * The dataset included 16 columns with a mix of numeric variables (e.g., price, minimum\_nights, number\_of\_reviews, reviews\_per\_month, availability\_365, calculated\_host\_listings\_count) and categorical variables (e.g., neighbourhood\_group, neighbourhood, room\_type, last\_review), capturing both host and listing characteristics.
#
#
# **Approach:**
#
# * Conducted exploratory data analysis using 15 visualizations (bar charts, scatter plots, heatmaps, pair plots) to uncover relationships among variables like price, location, room type, reviews, and availability.
#
#
# **Key Insights:**
#
# * Manhattan listings command higher prices (around \$200/night) than Queens or the Bronx (\$80/night). Entire homes are the most expensive and popular room type.
# * High-demand areas like Brooklyn and Manhattan (especially Williamsburg) dominate listings, while Staten Island remains underserved.
# * Higher-priced listings often have fewer reviews and higher availability, suggesting lower demand or potential overpricing.
# * Seasonal trends show review peaks in summer, with longer minimum stays often linked to lower prices.
#
#
#
# **Tools:**
#
# * Python with pandas, matplotlib, and seaborn for data processing and visualization.
#
#
# **Business Solutions:**
#
# * **Dynamic Pricing Tools:** Suggest optimal rates for hosts based on location, room type, and demand to maximize revenue.
# * **Review Enhancement:** Encourage hosts to solicit more guest reviews to build trust and boost appeal.
# * **Targeted Marketing:** Promote high-demand areas while incentivizing hosts in underserved boroughs to expand listings.
# * **Availability Optimization:** Adjust pricing and minimum stay policies to reduce excess availability and increase bookings.
# * **Personalized Recommendations:** Enhance the recommendation engine to better match guest preferences, improving satisfaction.
# * **Seasonal and Niche Offerings:** Introduce bundled and budget options to attract a broader audience and balance demand.
#
#
# **Impact:**
#
# * **Host Performance:** Empowers hosts with data-driven strategies to improve revenue and utilization.
# * **Customer Satisfaction:** Enhances guest experiences through tailored options, fostering loyalty.
# * **Revenue and Competitiveness:** Drives bookings, expands market reach, and strengthens Airbnb’s position in NYC, fueling overall platform success.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Since 2008, guests and hosts have used Airbnb to expand on travelling possibilities and present a more unique, personalised way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analysed and used for security, business decisions, understanding of customers' and providers' (hosts) behaviour and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more. This dataset has around 49,000 observations in it with 16 columns and it is a mix of categorical and numeric values. Explore and analyse the data to discover key understandings.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To leverage data analysis of Airbnb’s NYC listings to optimize host performance and enhance customer satisfaction, thereby increasing overall platform revenue and market competitiveness.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
airbnb_df = pd.read_excel('/content/drive/My Drive/Datasets/Airbnb NYC 2019.xlsx')
airbnb_df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
airbnb_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
airbnb_df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48869 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48873 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
airbnb_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
Null_val = airbnb_df.isnull().sum()
Null_val
# Out:
# id                                    0
# name                                 26
# host_id                               0
# host_name                            22
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
missing_val = airbnb_df.isnull().sum()
missing_val = missing_val[missing_val > 0]  # Only show columns with missing values

plt.figure(figsize=(6, 4))
sns.barplot(x=missing_val.index, y=missing_val.values, palette="Set2")
plt.ylabel("Missing Values Count")
plt.title("Missing Values Per Column")
plt.show()
# Out:
# <ipython-input-11-e440001b0f23>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=missing_val.index, y=missing_val.values, palette="Set2")

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This dataset contains 48,895 observations spread across 16 columns, featuring a mix of categorical and numerical data. It represents Airbnb listings in New York City. Most columns are complete, though name and host_name have a few missing values. However, last_review and reviews_per_month show substantial missing data, likely because some listings have no reviews.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
airbnb_df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
#
#        minimum_nights  number_of_reviews                    last_review  \
# count    48895.000000       48895.000000                          38843
# mean         7.029962          23.274466  2018-10-04 01:47:23.910099456
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1. id - Unique identifier for each listing.
# 2. name - Name or title of the listing.
# 3. host_id - Unique identifier for the host.
# 4. host_name - Name of the host.
# 5. neighbourhood_group - Main neighborhood group in NYC (e.g., Manhattan, Brooklyn).
# 6. neighbourhood - Specific neighborhood where the listing is located.
# 7. latitude - Geographic coordinate for latitude.
# 8. longitude - Geographic coordinate for longitude.
# 9. room_type - Type of listing (Entire home/apt, Private room, Shared room).
# 10. price - Cost per night in USD.
# 11. minimum_nights - Minimum number of nights required for booking.
# 12. number_of_reviews - Total number of reviews for the listing.
# 13. last_review - Date of the most recent review (if available).
# 14. reviews_per_month - Average number of reviews received per month.
# 15. calculated_host_listings_count - Number of listings the host has.
# 16. availability_365 - Number of days the listing is available in a year.Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
Unique_val = airbnb_df.nunique()
Unique_val
# Out:
# id                                48895
# name                              47895
# host_id                           37457
# host_name                         11451
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# Handling Missing Values
airbnb_df['name'].fillna('Unknown', inplace=True)
airbnb_df['host_name'].fillna('Unknown', inplace=True)
airbnb_df['last_review'] = pd.to_datetime(airbnb_df['last_review'])  # Converting to datetime
airbnb_df['reviews_per_month'].fillna(0, inplace=True)  # No reviews = 0 reviews per month

# Optimizing Data Types
categorical_columns = ['neighbourhood_group', 'neighbourhood', 'room_type']
for col in categorical_columns:
    airbnb_df[col] = airbnb_df[col].astype('category')  # Converting to category to save memory

# Removing Duplicates
airbnb_df.drop_duplicates(inplace=True)

# Handling Outliers
airbnb_df = airbnb_df[airbnb_df['price'] > 0]  # Removing listings with 0 price (unrealistic)
airbnb_df = airbnb_df[airbnb_df['minimum_nights'] <= 365]  # Removing extreme minimum_nights values

# Displaying the cleaned dataset information
airbnb_df.info(), airbnb_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48870 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48870 non-null  int64
#  1   name                            48870 non-null  object
#  2   host_id                         48870 non-null  int64
#  3   host_name                       48870 non-null  object
#  4   neighbourhood_group             48870 non-null  category
#  5   neighbourhood                   48870 non-null  category
#  6   latitude                        48870 non-null  float64
#  7   longitude                       48870 non-null  float64
#  8   room_type                       48870 non-null  category
#  9   price                           48870 non-null  int64
#  10  minimum_nights                  48870 non-null  int64
#  11  number_of_reviews               48870 non-null  int64
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# # **Data Manipulations (Cleaning & Preprocessing)**
#
# ***1. Handling Missing Values:***
# *   name and host_name: Replaced missing values with “Unknown.”
# *   last_review: Converted to datetime format; missing values retained as NaT.
# *   reviews_per_month: Filled missing values with 0, assuming no reviews equate to zero reviews per month.
#
# ***2. Optimizing Data Types:***
# *   Converted categorical columns (neighbourhood_group, neighbourhood, room_type) to category type.
# *   Converted last_review to datetime to enable time-based analysis.
#
# ***3. Removing Duplicates:***
# *   Checked for and removed any duplicate rows — none remain.
#
# ***4. Handling Outliers:***
# *   Removed listings with price = 0, as they are unrealistic.
# *   Capped minimum_nights at 365 to correct likely data entry errors.
#
# # **Insights from the Data:**
#
# ***Host Activity & Listings:***
# *   Some hosts manage multiple listings (one host_id can appear in several listings).
# *   Listings are distributed across 221 neighborhoods within 5 boroughs (neighbourhood_group).
#
# ***Room Type & Pricing Trends:***
#
# *   The dataset contains three room types: Entire home/apt, Private room, and Shared room.
# *   Prices vary significantly (674 unique values), warranting further analysis to identify patterns.
#
# ***Review & Availability Trends:***
# *   Some listings have never been reviewed (reviews_per_month = 0).
# *   Availability ranges widely — some listings are available year-round (availability_365 = 365), while others are never available (availability_365 = 0).

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ## Chart - 1 - Bar Chart - Average Price by Neighbourhood Group

# %%
# Chart - 1
sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
avg_price_by_ng = airbnb_df.groupby('neighbourhood_group')['price'].mean().sort_values()
avg_price_by_ng.plot(kind='bar', color='greenyellow')
plt.title('Average Price by Neighbourhood Group')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Average Price ($)')
plt.xticks(rotation=45)
for i, v in enumerate(avg_price_by_ng):
    plt.text(i, v + 5, f'{v:.0f}', ha='center')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-16-8e9de85788d2>:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_price_by_ng = airbnb_df.groupby('neighbourhood_group')['price'].mean().sort_values()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are excellent for comparing a numerical variable (like price) across different categorical groups (such as neighborhoods).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Manhattan likely has the highest average price per night (around $200), while Queens or the Bronx are typically lower (around $80 per night)

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   Positive Strategy: This analysis can help Airbnb prioritize marketing luxury listings in Manhattan or budget options in Queens, effectively tailoring their strategies to different customer segments.
#
# *   Negative Growth Insights: No direct negative insight: However, focusing too heavily on high-priced areas could risk alienating budget travelers who may prefer more affordable options elsewhere.

# %% [markdown]
# #Chart - 2 - Box Plot - Price Distribution by Room Type

# %%
# Chart - 2
plt.figure(figsize=(10, 6))
sns.boxplot(x='room_type', y='price', data=airbnb_df, color='plum')
plt.yscale('log')
plt.title('Price Distribution by Room Type')
plt.xlabel('Room Type')
plt.ylabel('Price ($ - Log Scale)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Box plots are useful for visualizing the spread, median, and outliers of numerical data across different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  *   Entire homes typically have the highest median price (around $250 ) and a wider range than private rooms ( $100 ) or shared rooms ( $50).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   Positive Strategy:   Hosts can use these insights to adjust pricing strategies based on room type norms, helping them optimize revenue.
# *   Negative Growth Insights: Extreme outliers (for example, prices over $1,000 for shared rooms) could confuse or deter customers, potentially leading to fewer bookings.

# %% [markdown]
# #Chart - 3 - Bar Chart - Number of Listings by Neighbourhood Group

# %%
# Chart - 3
plt.figure(figsize=(10, 6))
listing_counts = airbnb_df['neighbourhood_group'].value_counts()
listing_counts.plot(kind='barh', color='orange')
plt.title('Number of Listings by Neighbourhood Group')
plt.xlabel('Number of Listings')
plt.ylabel('Neighbourhood Group')
for i, v in enumerate(listing_counts):
    plt.text(v + 50, i, str(v), va='center')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are effective for counting occurrences across categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Brooklyn and Manhattan likely have the most listings (around 15,000 each), while Staten Island has the fewest (around 500).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   Positive Strategy: Prioritizing areas with high listings can help maximize visibility and bookings.
# *   Negative Growth Insights: Underrepresentation in smaller boroughs may lead to missed opportunities in niche markets, potentially limiting overall growth.

# %% [markdown]
# # Chart - 4 - Pie Chart - Distribution of Room Types

# %%
# Chart - 4
plt.figure(figsize=(8, 8))
room_type_counts = airbnb_df['room_type'].value_counts()
plt.pie(room_type_counts, labels=room_type_counts.index, autopct='%1.1f%%', colors=['Orchid','mediumslateblue', 'darkorchid'])
plt.title('Distribution of Room Types')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts are useful for illustrating the composition of a categorical variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Entire homes/apartments likely dominate (about 50%), followed by private rooms (40%) and shared rooms (10%).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   Positive Strategy: Understanding room type preferences can help hosts focus on offering what’s in demand, such as entire homes.
#
# *   Negative Growth Insights: Low demand for shared rooms may indicate a shrinking market segment, which could reduce revenue potential if hosts focus too much on that option.

# %% [markdown]
# # Chart - 5 - Histogram - Distribution of Price

# %%
# Chart - 5
plt.figure(figsize=(10, 6))
sns.histplot(airbnb_df['price'].dropna(), bins=50, kde=True, color='darkturquoise')
plt.xscale('log')
plt.title('Distribution of Price')
plt.xlabel('Price ($ - Log Scale)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histograms display the frequency distribution of a continuous variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Most prices cluster between $50 and $300, with a long tail of more expensive listings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   Positive Strategy: Identifying common price ranges helps hosts set competitive rates.
# *   Negative Growth Insights: A skewed distribution might reveal an oversaturation of low-priced listings, which could reduce profit margins and overall profitability.

# %% [markdown]
# # Chart - 6 - Bar Chart - Average Availability by Neighbourhood Group

# %%
# Chart - 6

plt.figure(figsize=(10, 6))
avg_availability = airbnb_df.groupby('neighbourhood_group')['availability_365'].mean().sort_values()
avg_availability.plot(kind='bar', color=sns.color_palette('viridis', len(avg_availability)))
plt.title('Average Availability by Neighbourhood Group')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Average Availability (Days/Year)')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-28-8ff62bc76a1f>:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_availability = airbnb_df.groupby('neighbourhood_group')['availability_365'].mean().sort_values()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Bar charts are effective for comparing averages across categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Manhattan likely has lower availability (around 100 days per year) due to high demand, while Queens has higher availability (around 200 days).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   Positive Strategy: Targeting high-availability areas for promotions can help increase bookings.
# *   Negative Growth Insights: Low availability in prime areas might indicate overbooking, which could lead to customer dissatisfaction and potential loss of repeat business.

# %% [markdown]
# # Chart - 7 - Scatter Plot - Price vs. Number of Reviews

# %%
# Chart - 7
plt.figure(figsize=(10, 6))
sns.scatterplot(x='number_of_reviews', y='price', hue='room_type', data=airbnb_df, alpha=0.5)
plt.yscale('log')
plt.title('Price vs. Number of Reviews')
plt.xlabel('Number of Reviews')
plt.ylabel('Price ($ - Log Scale)')
plt.legend(title='Room Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plots are great for exploring relationships between two continuous variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Higher-priced listings often have fewer reviews, while mid-range listings (around $100–$200) tend to receive more reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   Positive Strategy:
# Encouraging reviews for premium listings could increase their attractiveness to potential guests.
# *   Negative Growth Insights:
# Low review counts for expensive listings might indicate poor customer satisfaction or low occupancy rates.

# %% [markdown]
# # Chart - 8 - Line Chart - Reviews per Month Over Time

# %%
# Chart - 8
airbnb_df['review_month'] = airbnb_df['last_review'].dt.to_period('M')
monthly_reviews = airbnb_df.groupby('review_month')['reviews_per_month'].mean().dropna()
plt.figure(figsize=(12, 6))
monthly_reviews.plot(kind='line', marker='o', color='teal')
plt.title('Average Reviews per Month Over Time')
plt.xlabel('Month')
plt.ylabel('Average Reviews per Month')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line charts are ideal for tracking trends over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Reviews peak in summer (about 2.5 reviews per month in June) and dip in winter (around 1 review per month in January).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   Positive Strategy: Seasonal marketing efforts can leverage peak review periods to boost engagement.
# *   Negative Growth Insights:
# Lower reviews in winter may reflect decreased travel demand, leading to reduced revenue during these months.

# %% [markdown]
# # Chart - 9 - Stacked Bar Chart - Room Type Distribution by Neighbourhood Group

# %%
# Chart - 9
plt.figure(figsize=(12, 6))
room_type_by_ng = pd.crosstab(airbnb_df['neighbourhood_group'], airbnb_df['room_type'])
room_type_by_ng.plot(kind='bar', stacked=True, colormap='Set2')
plt.title('Room Type Distribution by Neighbourhood Group')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Number of Listings')
plt.legend(title='Room Type')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Stacked bar charts effectively display the composition of categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Manhattan has a higher proportion of entire homes, while Brooklyn shows a more balanced mix of private rooms and entire homes.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   Positive Strategy:
# Tailoring listings to match borough-specific preferences can help boost demand.
# *   Negative Growth Insights:
# Overreliance on a single room type in each area may overlook diverse customer needs, potentially limiting revenue opportunities.

# %% [markdown]
# # Chart - 10 - Violin Plot - Price Distribution by Neighbourhood Group

# %%
# Chart - 10
plt.figure(figsize=(12, 6))
sns.violinplot(x='neighbourhood_group', y='price', data=airbnb_df, color='chartreuse')
plt.yscale('log')
plt.title('Price Distribution by Neighbourhood Group')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Price ($ - Log Scale)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Violin plots combine density and spread, providing more detail than box plots.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Manhattan shows a wider price distribution (around $50–$1,000), while the Bronx has a narrower range (around $30–$150).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *    Positive Strategy:
# Hosts can tailor and diversify their pricing strategies based on the unique price distributions of each borough.
#
# *    Negative Growth Insights:
# Narrow price ranges in some areas may limit pricing flexibility, potentially reducing profitability and competitiveness.

# %% [markdown]
# # Chart - 11 - Scatter Plot - Availability vs. Price

# %%
# Chart - 11
plt.figure(figsize=(10, 6))
sns.scatterplot(x='availability_365', y='price', size='number_of_reviews', data=airbnb_df, alpha=0.5, color='mediumturquoise')
plt.yscale('log')
plt.title('Availability vs. Price')
plt.xlabel('Availability (Days/Year)')
plt.ylabel('Price ($ - Log Scale)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plots are great for exploring relationships between multiple variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Higher-priced listings often show higher availability, which may suggest lower demand compared to more competitively priced options.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   Positive Strategy:
# Adjusting pricing for high-availability listings could attract more bookings.
# *
# Negative Growth Insights:
# High availability coupled with high prices may indicate overpricing, which could deter potential guests and reduce revenue.

# %% [markdown]
# # Chart - 12 - Bar Chart - Top 10 Neighbourhoods by Listing Count

# %%
# Chart - 12
plt.figure(figsize=(12, 6))
top_neighbourhoods = airbnb_df['neighbourhood'].value_counts().head(10)
top_neighbourhoods.plot(kind='bar', color='gold')
plt.title('Top 10 Neighbourhoods by Listing Count')
plt.xlabel('Neighbourhood')
plt.ylabel('Number of Listings')
plt.xticks(rotation=45)
for i, v in enumerate(top_neighbourhoods):
    plt.text(i, v + 10, str(v), ha='center')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts effectively highlight top performers within categorical data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Williamsburg and Harlem likely lead with the highest number of listings, approximately 2,000 each.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *  Positive Strategy:
# Focusing on popular neighborhoods can help maximize exposure and bookings.
#
# *  Negative Growth Insights:
# Overlooking smaller neighborhoods may cause missed opportunities in emerging markets.

# %% [markdown]
# # Chart - 13 - Bar Chart - Average Price by Minimum Nights

# %%
# Chart - 13
airbnb_df['min_nights_bin'] = pd.cut(airbnb_df['minimum_nights'], bins=[0, 3, 7, float('inf')], labels=['1-3', '4-7', '8+'])
plt.figure(figsize=(10, 6))
avg_price_by_min_nights = airbnb_df.groupby('min_nights_bin')['price'].mean()
avg_price_by_min_nights.plot(kind='bar', color='palevioletred')
plt.title('Average Price by Minimum Nights')
plt.xlabel('Minimum Nights')
plt.ylabel('Average Price ($)')
plt.xticks(rotation=0)
plt.show()
# Out:
# <ipython-input-40-c58fe500f9e5>:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_price_by_min_nights = airbnb_df.groupby('min_nights_bin')['price'].mean()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts effectively compare averages across grouped data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Listings with longer minimum stays (8+ nights) tend to have higher average prices (around $170) compared to those with shorter stays (around $150).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *  Positive Strategy:
# Offering discounts for longer stays can attract travelers looking for extended bookings.
#
# *  Negative Growth Insights:
# High minimum night requirements may discourage short-term guests, potentially lowering overall occupancy rates.

# %% [markdown]
# # Chart - 14 - Correlation Heatmap - - Numerical Variables

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(10, 8))
numeric_cols = ['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month',
                'calculated_host_listings_count', 'availability_365']
corr_matrix = airbnb_df[numeric_cols].corr()
sns.heatmap(corr_matrix, annot=True, vmin=-1, vmax=1)
sns.color_palette("YlOrBr", as_cmap=True)
plt.title('Correlation Heatmap of Numerical Variables')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Heatmaps effectively visualize relationships between multiple numerical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is a weak negative correlation between price and number of reviews (approximately -0.2), suggesting that lower-priced listings tend to receive more reviews.

# %% [markdown]
# # Chart - 15 - Pair Plot - Numerical Variables

# %%
# Pair Plot visualization code
sns.pairplot(airbnb_df[['price', 'minimum_nights', 'number_of_reviews', 'availability_365', 'room_type']],
             hue='room_type', diag_kind='hist', plot_kws={'alpha': 0.5})
plt.suptitle('Pair Plot of Numerical Variables by Room Type', y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pair plots provide a comprehensive view of both relationships and distributions across multiple variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Price and availability cluster by room type, with entire homes tending to have higher prices and greater availability than other room types.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1. **Host Performance:**
# Dynamic pricing, encouraging reviews, and optimizing availability empower hosts to increase earnings and maintain active listings.
#
# 2. **Customer Satisfaction:**
# Tailored recommendations and flexible options enhance the guest experience and build loyalty.
#
# 3. **Revenue and Competitiveness:**
# Targeted marketing and innovative offerings drive bookings and expand market reach.
#
# 4. **Optimizing Pricing Strategies:**
# Leverage machine learning models (such as regression analysis) to forecast optimal listing prices based on location, property type, seasonality, and guest reviews. Provide dynamic pricing recommendations that help hosts maximize both occupancy and revenue.
#
# 5. **Enhancing Customer and Host Experience:**
# Use sentiment analysis on guest reviews to understand customer satisfaction and recommend improvements for hosts. Highlight the top amenities and features that boost bookings, and guide hosts to prioritize them. Apply clustering techniques to segment guests by booking behaviors and preferences for more personalized experiences.
#
#
# 6. **Strengthening Platform Security:**
# Deploy anomaly detection algorithms to identify suspicious or fraudulent listings (e.g., fake reviews, duplicates). Apply natural language processing (NLP) to detect potential scams or misleading descriptions in listings.
#
#
# 7. **Targeted Marketing Strategies:**
# Develop personalized marketing campaigns informed by guest segmentation. Identify peak travel seasons and high-demand locations to sharpen Airbnb’s advertising efforts. Utilize A/B testing to refine pricing discounts, promotions, and new features for greater engagement.
#
#
# 8. **Business Expansion and Service Innovation:**
# Identify underutilized or high-growth areas where Airbnb can attract more hosts. Build AI-powered recommendations for users based on past bookings and browsing history. Explore additional services such as travel packages, premium listings, and experience-based stays to expand revenue streams.
#
# * By implementing these data-driven strategies, Airbnb can enhance its ecosystem—ensuring hosts thrive, guests are delighted, and the platform stays ahead in the travel industry, ultimately driving sustainable revenue growth.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This project demonstrates how data analysis can transform raw listing data into actionable strategies aligned with Airbnb’s objectives: informed business decisions, effective marketing, and innovation. Implementing these solutions will empower the client to achieve sustainable growth and maintain its leadership in personalized travel experiences.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***

# %%
import pandas as pd

# Assuming `df` is your cleaned DataFrame
airbnb_df.to_csv('cleaned_data.csv', index=False)  # Saves the file in the Colab environment

# %%
from google.colab import files

files.download('cleaned_data.csv')  # Triggers a download

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp cleaned_data.csv "/content/drive/My Drive/Datasets/"
